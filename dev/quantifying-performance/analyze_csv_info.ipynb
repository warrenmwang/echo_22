# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
import numpy as np

# %%
name = 'Original_Pretrained_R2plus1DMotionSegNet.pth.csv'
data = pd.read_csv(f'./csvs/{name}')
save_hists_as_svg = False

# %%
data.columns
# Out:
# Index(['Video Index', 'Predicted EF', 'True EF', 'Seg GLS', 'Warp GLS',
#        'True GLS', 'Seg ED Dice', 'Seg ES Dice', 'Warp ED Dice',
#        'Warp ES Dice'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Predicted EF      True EF      Seg GLS     Warp GLS     True GLS  \
# count   1111.000000  1111.000000  1111.000000  1111.000000  1111.000000
# mean      57.660572    55.651562    -0.155008    -0.174877    -0.131506
# std       11.830781    12.095286     0.066949     0.104513     0.559186
# min       10.039696    10.192957    -0.366337    -0.404040    -0.678832
# 25%       53.011067    51.927948    -0.198113    -0.222222    -0.196721
# 50%       59.691563    58.754887    -0.161290    -0.182540    -0.160920
# 75%       65.565989    63.574314    -0.115544    -0.138889    -0.118546
# max       87.289323    84.452354     0.244681     2.484848    17.714286
#
#        Seg ED Dice  Seg ES Dice  Warp ED Dice  Warp ES Dice
# count  1111.000000  1111.000000   1111.000000   1111.000000
# mean      0.936521     0.907664      0.936171      0.912578
# std       0.029099     0.049415      0.028574      0.045683
# min       0.682607     0.449400      0.676852      0.450435
# 25%       0.923341     0.888903      0.923179      0.894693
# 50%       0.942648     0.918592      0.942120      0.923935
# 75%       0.956883     0.941129      0.955779      0.942580
# max       0.983438     0.975293      0.978547      0.977159

# %%
low_efs = data.query("`Predicted EF` < 50")
normal_efs = data.query("`Predicted EF` >= 50 and `Predicted EF` <= 70")
high_efs = data.query("`Predicted EF` > 70")

low_efs.describe()
# Out:
#        Predicted EF     True EF     Seg GLS    Warp GLS    True GLS  \
# count    221.000000  221.000000  221.000000  221.000000  221.000000
# mean      38.971122   37.889432   -0.100070   -0.114590   -0.084476
# std        9.738119   12.632978    0.060964    0.066281    0.153940
# min       10.039696   10.192957   -0.337662   -0.298246   -0.275510
# 25%       33.786188   27.645145   -0.135135   -0.152381   -0.142857
# 50%       42.062156   37.387440   -0.098214   -0.120879   -0.097902
# 75%       46.920715   48.141052   -0.059829   -0.072072   -0.059829
# max       49.943208   69.863739    0.107143    0.114583    1.162162
#
#        Seg ED Dice  Seg ES Dice  Warp ED Dice  Warp ES Dice
# count   221.000000   221.000000    221.000000    221.000000
# mean      0.939540     0.921797      0.940044      0.923766
# std       0.030582     0.045521      0.029256      0.043357
# min       0.682607     0.674184      0.676852      0.674556
# 25%       0.929626     0.904427      0.930373      0.914108
# 50%       0.945308     0.936170      0.944196      0.935938
# 75%       0.958443     0.951968      0.957298      0.950820
# max       0.983438     0.975293      0.977331      0.971455

# %%
normal_efs.describe()
# Out:
#        Predicted EF     True EF     Seg GLS    Warp GLS    True GLS  \
# count    781.000000  781.000000  781.000000  781.000000  781.000000
# mean      60.710831   59.218980   -0.166071   -0.185586   -0.138188
# std        5.182294    6.560303    0.059828    0.110885    0.660999
# min       50.085073   29.127012   -0.339450   -0.393750   -0.678832
# 25%       56.630980   55.967918   -0.202899   -0.224638   -0.204082
# 50%       60.846058   59.670322   -0.169811   -0.191011   -0.170213
# 75%       64.913843   63.551777   -0.130952   -0.154545   -0.134146
# max       69.895060   84.452354    0.244681    2.484848   17.714286
#
#        Seg ED Dice  Seg ES Dice  Warp ED Dice  Warp ES Dice
# count   781.000000   781.000000    781.000000    781.000000
# mean      0.936578     0.906655      0.936143      0.912910
# std       0.028139     0.048295      0.027812      0.043686
# min       0.740185     0.449400      0.793912      0.450435
# 25%       0.923037     0.889136      0.921899      0.896652
# 50%       0.942571     0.917326      0.942128      0.922195
# 75%       0.957009     0.938511      0.955785      0.941348
# max       0.980471     0.972238      0.978547      0.977159

# %%
high_efs.describe()
# Out:
#        Predicted EF     True EF     Seg GLS    Warp GLS    True GLS  \
# count    109.000000  109.000000  109.000000  109.000000  109.000000
# mean      73.698329   66.103648   -0.187128   -0.220377   -0.178986
# std        3.127698    4.449005    0.067397    0.064481    0.053029
# min       70.002757   48.009235   -0.366337   -0.404040   -0.345238
# 25%       71.439430   63.978722   -0.231884   -0.258065   -0.211009
# 50%       72.807871   66.340637   -0.191011   -0.220779   -0.178571
# 75%       74.707107   68.647682   -0.152174   -0.173228   -0.153846
# max       87.289323   77.112564    0.121739   -0.068376    0.050633
#
#        Seg ED Dice  Seg ES Dice  Warp ED Dice  Warp ES Dice
# count   109.000000   109.000000    109.000000    109.000000
# mean      0.929987     0.886238      0.928519      0.887516
# std       0.031890     0.056133      0.031177      0.054274
# min       0.803468     0.617809      0.805646      0.606257
# 25%       0.912999     0.866995      0.912642      0.870936
# 50%       0.936700     0.898305      0.934050      0.895522
# 75%       0.953744     0.920128      0.952074      0.923935
# max       0.974725     0.960967      0.973559      0.965005

# %%
truth_low_efs = data.query("`True EF` < 50")
truth_normal_efs = data.query("`True EF` >= 50 and `True EF` <= 70")
truth_high_efs = data.query("`True EF` > 70")

truth_low_efs.describe()
# Out:
#        Predicted EF     True EF     Seg GLS    Warp GLS    True GLS  \
# count    243.000000  243.000000  243.000000  243.000000  243.000000
# mean      42.157378   36.534189   -0.104540   -0.121029   -0.087046
# std       12.013018   10.081765    0.063399    0.068753    0.122929
# min       10.039696   10.192957   -0.337662   -0.336538   -0.269565
# 25%       34.546735   28.406661   -0.142857   -0.156725   -0.137356
# 50%       43.867298   38.528938   -0.104167   -0.125000   -0.096154
# 75%       50.508982   45.323078   -0.064598   -0.080179   -0.056971
# max       73.367947   49.884445    0.112360    0.114583    1.100000
#
#        Seg ED Dice  Seg ES Dice  Warp ED Dice  Warp ES Dice
# count   243.000000   243.000000    243.000000    243.000000
# mean      0.938758     0.927805      0.939422      0.927812
# std       0.030951     0.037231      0.030042      0.035783
# min       0.682607     0.674184      0.676852      0.674556
# 25%       0.927532     0.917754      0.929597      0.918639
# 50%       0.944409     0.936725      0.944221      0.935915
# 75%       0.958484     0.950506      0.957546      0.950255
# max       0.983438     0.975293      0.978547      0.971455

# %%
truth_normal_efs.describe()
# Out:
#        Predicted EF     True EF     Seg GLS    Warp GLS    True GLS  \
# count    837.000000  837.000000  837.000000  837.000000  837.000000
# mean      61.730354   60.555115   -0.169044   -0.189158   -0.142175
# std        7.131843    4.779425    0.060308    0.108814    0.640209
# min       33.986387   50.005959   -0.366337   -0.404040   -0.678832
# 25%       56.942533   57.136208   -0.205882   -0.227273   -0.206897
# 50%       61.754194   60.396355   -0.172185   -0.194444   -0.172414
# 75%       66.682282   64.293854   -0.133333   -0.156250   -0.141176
# max       84.047630   69.863739    0.244681    2.484848   17.714286
#
#        Seg ED Dice  Seg ES Dice  Warp ED Dice  Warp ES Dice
# count   837.000000   837.000000    837.000000    837.000000
# mean      0.936404     0.904633      0.935806      0.910493
# std       0.028432     0.047331      0.027950      0.044347
# min       0.740185     0.449400      0.793912      0.450435
# 25%       0.923037     0.886859      0.922095      0.892069
# 50%       0.942688     0.913410      0.942065      0.919840
# 75%       0.956727     0.936968      0.955373      0.939920
# max       0.980804     0.972238      0.977558      0.977159

# %%
truth_high_efs.describe()
# Out:
#        Predicted EF    True EF    Seg GLS   Warp GLS   True GLS  Seg ED Dice  \
# count     31.000000  31.000000  31.000000  31.000000  31.000000    31.000000
# mean      69.301482  73.111181  -0.171634  -0.211384  -0.191959     0.922140
# std        6.951096   3.208285   0.075183   0.074234   0.054631     0.028635
# min       57.032995  70.022636  -0.298969  -0.393750  -0.310345     0.853282
# 25%       65.951605  71.014545  -0.219938  -0.246053  -0.235421     0.900643
# 50%       67.930455  71.922012  -0.184783  -0.208333  -0.185185     0.917582
# 75%       71.856562  74.696510  -0.120668  -0.163144  -0.149001     0.943983
# max       87.289323  84.452354   0.022472  -0.075949  -0.117021     0.963253
#
#        Seg ES Dice  Warp ED Dice  Warp ES Dice
# count    31.000000     31.000000     31.000000
# mean      0.831630      0.920544      0.849453
# std       0.084987      0.028614      0.077243
# min       0.634421      0.860858      0.639821
# 25%       0.810307      0.900106      0.823061
# 50%       0.852496      0.921687      0.864407
# 75%       0.882726      0.942543      0.893348
# max       0.955951      0.966029      0.956938

# %% [markdown]
# ## First just try look at the distribution of Ejection Fractions, GLS, ED/ES Dice

# %%
# def createHist(x, column, xlabel, ylabel):
#     fig = plt.figure(figsize=(20,10))
#     plt.hist(x[column], bins=100);
#     plt.title(column)
#     plt.xlabel(xlabel)
#     plt.ylabel(ylabel)
#     plt.show()

# %%
# createHist(data, 'Predicted EF', 'Volume Percentage', 'Count')

# %%
# createHist(data, 'True EF', 'Volume Percentage', 'Count')

# %%
# createHist(data, 'Predicted GLS', 'Strain Percentage', 'Count')

# %%
# createHist(data, 'True GLS', 'Strain Percentage', 'Count')

# %%
# createHist(data, 'ED Dice', 'Overlap Percentage', 'Count')

# %%
# createHist(data, 'ES Dice', 'Overlap Percentage', 'Count')

# %% [markdown]
# ## Try to plot 3 different distributions of GLS's based on EF value (low, normal, high)

# %%
# _min = -0.35 * 100
# _max = 0.20 * 100
# step = 0.01 * 100

# %%
# low_efs = data.query("`Predicted EF` < 50")
# normal_efs = data.query("`Predicted EF` >= 50 and `Predicted EF` <= 70")
# high_efs = data.query("`Predicted EF` > 70")

# # multiple values by 100 to change data representation from decimal as a percent to regular value as a percent
# low_efs['Predicted GLS'] *= 100
# normal_efs['Predicted GLS'] *= 100
# high_efs['Predicted GLS'] *= 100

# fig, ax = plt.subplots(1,1,figsize=(20,10))
# plt.hist(low_efs['Predicted GLS'], bins=np.arange(_min, _max, step), color='blue', alpha=0.5, label='EF < 50%')
# plt.hist(normal_efs['Predicted GLS'], bins=np.arange(_min, _max, step), color='green', alpha=0.5, label='EF in [50, 70]')
# plt.hist(high_efs['Predicted GLS'], bins=np.arange(_min, _max, step), color='red', alpha=0.5, label='EF > 70%')

# plt.xticks(rotation = -45)

# loc = plticker.MultipleLocator(base=step) # this locator puts ticks at regular intervals
# ax.xaxis.set_major_locator(loc)

# # labels = [item for item in ax.get_xticklabels()]

# plt.legend()
# plt.title('Predicted GLS Distributions')
# plt.xlabel('Strain Percentage')
# plt.ylabel('Count')
# if save_hists_as_svg:
#     plt.savefig(f'./images/{name}_predicted_hist.svg')

# plt.show()

# # print(labels)
# # print(labels[0])
# # print(type(labels[0]))

# %%
# truth_low_efs = data.query("`True EF` < 50")
# truth_normal_efs = data.query("`True EF` >= 50 and `True EF` <= 70")
# truth_high_efs = data.query("`True EF` > 70")

# truth_low_efs['True GLS'] *= 100
# truth_normal_efs['True GLS'] *= 100
# truth_high_efs['True GLS'] *= 100

# fig, ax = plt.subplots(1,1,figsize=(20,10))
# plt.hist(truth_low_efs['True GLS'], bins=np.arange(_min, _max, step), color='blue', alpha=0.5, label='EF < 50%')
# plt.hist(truth_normal_efs['True GLS'], bins=np.arange(_min, _max, step), color='green', alpha=0.5, label='EF in [50, 70]')
# plt.hist(truth_high_efs['True GLS'], bins=np.arange(_min, _max, step), color='red', alpha=0.5, label='EF > 70%')

# plt.xticks(rotation = -45)

# loc = plticker.MultipleLocator(base=step) # this locator puts ticks at regular intervals
# ax.xaxis.set_major_locator(loc)


# plt.legend()
# plt.title('Ground Truth GLS Distributions')
# plt.xlabel('Strain Percentage')
# plt.ylabel('Count')
# if save_hists_as_svg:
#     plt.savefig(f'./images/{name}_truth_hist.svg')

# plt.show()

# %%
# data.describe()
